# %% [markdown]
# # ML model

# %% [markdown]
# #### Load Cleaned Dataset

# %%
import pandas as pd
df= pd.read_csv("cleaned_loan_dataset.csv")

# %% [markdown]
# #### difine Features and Target

# %%
x = df.drop("loan_paid_back",axis=1)
y = df["loan_paid_back"]

# %% [markdown]
# #### Split Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %% [markdown]
# #### Train the model

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### Make Predictions

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# #### Check accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.89625

# %% [markdown]
# #### confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[ 432  386]
#  [  29 3153]]

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.53      0.68       818
#            1       0.89      0.99      0.94      3182
#
#     accuracy                           0.90      4000
#    macro avg       0.91      0.76      0.81      4000
# weighted avg       0.90      0.90      0.88      4000

# %% [markdown]
# #### Find important features

# %%
importance = pd.DataFrame({
    "Feature": x.columns,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

print(importance.head(10))
# Out:
#                  Feature  Importance
# 6      employment_status    0.342429
# 7   debt_to_income_ratio    0.098697
# 8           credit_score    0.070537
# 11         interest_rate    0.047599
# 17       current_balance    0.042026
# 13           installment    0.041976
# 14        grade_subgrade    0.041748
# 16    total_credit_limit    0.040450
# 9            loan_amount    0.039711
# 5         monthly_income    0.038739

# %% [markdown]
# #### feature importance visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

sns.barplot(
    data=importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features Affecting Loan Repayment")
plt.xlabel("Importance Score")
plt.ylabel("Features")

plt.show()
