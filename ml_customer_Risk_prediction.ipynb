# %% [markdown]
# # ML model

# %% [markdown]
# #### Load Cleaned Dataset

# %%
import pandas as pd
df= pd.read_csv("cleaned_loan_dataset.csv")

# %%
features = [
    "age",
    "monthly_income",
    "interest_rate",
    "installment",
    "annual_income",
    "total_credit_limit",
    "current_balance",
    "delinquency_history",
    "debt_to_income_ratio",
    "credit_score",
    "loan_amount"
]

# %% [markdown]
# #### difine Features and Target

# %%
x = df[features]

y = df["loan_paid_back"]

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_scaled = scale.fit_transform(x)

# %% [markdown]
# #### Split Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=42)

# %% [markdown]
# #### Train the model

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### Make Predictions

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# #### Check accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.897

# %% [markdown]
# #### confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[ 431  387]
#  [  25 3157]]

# %% [markdown]
# #### Classification Report

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.53      0.68       818
#            1       0.89      0.99      0.94      3182
#
#     accuracy                           0.90      4000
#    macro avg       0.92      0.76      0.81      4000
# weighted avg       0.90      0.90      0.89      4000

# %% [markdown]
# #### Find important features

# %%
importance = pd.DataFrame({
    "Feature": x.columns,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

print(importance.head( 10))
# Out:
#                  Feature  Importance
# 10     employment_status    0.321082
# 11  debt_to_income_ratio    0.108803
# 12          credit_score    0.079825
# 2          interest_rate    0.057858
# 7        current_balance    0.053562
# 3            installment    0.051031
# 6     total_credit_limit    0.050194
# 13           loan_amount    0.049387
# 4          annual_income    0.048909
# 1         monthly_income    0.047025

# %% [markdown]
# #### feature importance visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))

sns.barplot(
    data=importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features Affecting Loan Repayment")
plt.xlabel("Importance Score")
plt.ylabel("Features")

plt.show()

# %%
import joblib
joblib.dump(model,"loan_model.pkl")
print("model saved sucessfully!")
# Out:
# model saved sucessfully!
